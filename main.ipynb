# %% [markdown]
# <a href="https://colab.research.google.com/github/huiping-cpu/ADALL_github/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello snake, long time no see.")
# Out:
# Hello snake, long time no see.
